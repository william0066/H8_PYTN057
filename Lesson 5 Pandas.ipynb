# %%
# Pandas berbentuk series dan dataframe, dataframe merupakan kumpulan dari series

# %%
import pandas as pd

# %%
a =[1,2,3,4]
print (a)
# Out:
# [1, 2, 3, 4]

# %%
a =[1,2,3,4]
b= pd.Series (a)
print (b)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
a= [1,2,3,4]
c= ['a','b','c','d']
b= pd.Series(a,index=c)
print (b)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
a = {'city': 'Amsterdam', 'name': "Anabele"}
b = pd.Series (a)
print (b)
# Out:
# city    Amsterdam
# name      Anabele
# dtype: object

# %%
import numpy as np
a =np.array ([1,2,3,4])
b =pd.Series (a)
print (b)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
a= [1,2,3,4]
b= pd.Series (a)
c = [5,6,7,8]
d=pd.Series (c)

e=pd.DataFrame({'column1': b, 'column 2': d})

print (e)

# kalau dataframe ga ada type dari object
# Out:
#    column1  column 2
# 0        1         5
# 1        2         6
# 2        3         7
# 3        4         8

# %%
# a=pd.read_csv ('masukin sumber file excel')
# a=pd.read_excel

# %%
a = pd.read_csv ('student-mat.csv')
print (a)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
a.shape
# Out:
# (395, 33)

# %%
a.tail(5) #5 terbawah
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
a.head (5) #5 teratas
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
pd.set_option('display.max.columns',None)

# %%
a.head ()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
a.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
a.index
# Out:
# RangeIndex(start=0, stop=395, step=1)

# %%
a.values
# Out:
# array([['GP', 'F', 18, ..., 5, 6, 6],
#        ['GP', 'F', 17, ..., 5, 5, 6],
#        ['GP', 'F', 15, ..., 7, 8, 10],
#        ...,
#        ['MS', 'M', 21, ..., 10, 8, 7],
#        ['MS', 'M', 18, ..., 11, 12, 10],
#        ['MS', 'M', 19, ..., 8, 9, 9]], dtype=object)

# %%
a['school'] #bentuknya series
# Out:
# 0      GP
# 1      GP
# 2      GP
# 3      GP
# 4      GP
#        ..
# 390    MS
# 391    MS
# 392    MS
# 393    MS
# 394    MS
# Name: school, Length: 395, dtype: object

# %%
a[['school']] #bentuknya dataframe
# Out:
#     school
# 0       GP
# 1       GP
# 2       GP
# 3       GP
# 4       GP
# ..     ...
# 390     MS
# 391     MS
# 392     MS
# 393     MS
# 394     MS
#
# [395 rows x 1 columns]

# %%
a[['school','age']] #bentuknya masih dataframe, column yg mo dipanggil
# Out:
#     school  age
# 0       GP   18
# 1       GP   17
# 2       GP   15
# 3       GP   15
# 4       GP   16
# ..     ...  ...
# 390     MS   20
# 391     MS   17
# 392     MS   21
# 393     MS   18
# 394     MS   19
#
# [395 rows x 2 columns]

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# ### **function describe untuk dataset integer berdasarkan Age & G1**

# %%
list_column_integer = ['school','age','G1']
a[list_column_integer].describe()
# Out:
#               age          G1
# count  395.000000  395.000000
# mean    16.696203   10.908861
# std      1.276043    3.319195
# min     15.000000    3.000000
# 25%     16.000000    8.000000
# 50%     17.000000   11.000000
# 75%     18.000000   13.000000
# max     22.000000   19.000000

# %% [markdown]
# ## **function describe untuk dataset string**

# %%
list_column_string = ['sex', 'address']
a[list_column_string].describe()
# Out:
#         sex address
# count   395     395
# unique    2       2
# top       F       U
# freq    208     307

# %% [markdown]
# ## **Counting jumlah data berdasarkan filter "sex"**

# %%
a['sex'].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %% [markdown]
# ## **Testing Loc & iLoc function**

# %%
a.loc[1] #label index
# Out:
# school             GP
# sex                 F
# age                17
# address             U
# famsize           GT3
# Pstatus             T
# Medu                1
# Fedu                1
# Mjob          at_home
# Fjob            other
# reason         course
# guardian       father
# traveltime          1
# studytime           2
# failures            0
# schoolsup          no
# famsup            yes
# paid               no
# activities         no
# nursery            no
# higher            yes
# internet          yes
# romantic           no
# famrel              5
# freetime            3
# goout               3
# Dalc                1
# Walc                1
# health              3
# absences            4
# G1                  5
# G2                  5
# G3                  6
# Name: 1, dtype: object

# %%
a.iloc[1] #positional index
# Out:
# school             GP
# sex                 F
# age                17
# address             U
# famsize           GT3
# Pstatus             T
# Medu                1
# Fedu                1
# Mjob          at_home
# Fjob            other
# reason         course
# guardian       father
# traveltime          1
# studytime           2
# failures            0
# schoolsup          no
# famsup            yes
# paid               no
# activities         no
# nursery            no
# higher            yes
# internet          yes
# romantic           no
# famrel              5
# freetime            3
# goout               3
# Dalc                1
# Walc                1
# health              3
# absences            4
# G1                  5
# G2                  5
# G3                  6
# Name: 1, dtype: object

# %%
## **Filter berdasarkan kategori gender**

# %%
filter_1 = a['sex'] == 'F'
print (filter_1)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# Name: sex, Length: 395, dtype: bool

# %%
a[filter_1]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   17       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   17       U     LE3       T     1     1   at_home     other
# 3       GP   F   17       U     GT3       T     4     2    health  services
# 4       GP   F   17       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 385     MS   F   17       R     GT3       T     2     2   at_home     other
# 386     MS   F   17       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   17       R     GT3       T     2     3  services     other
# 388     MS   F   17       U     LE3       T     3     1   teacher  services
# 389     MS   F   17       U     GT3       T     1     1     other     other
#
# ...
