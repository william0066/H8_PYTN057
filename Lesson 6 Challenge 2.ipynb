# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv ("fulltimeAL.csv")

# %%
df.head(5)
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
#
#                                          description    numreview  \
# 0  <span id="job_summary" class="summary"><div><d...          NaN
# 1  <span id="job_summary" class="summary"><div>Jo...          NaN
# 2  <span id="job_summary" class="summary"><div><d...          NaN
# 3  <span id="job_summary" class="summary"><p><b>D...   44 reviews
# 4  <span id="job_summary" class="summary"><div><h...  550 reviews
#
#              location
# 0  Atlanta, GA 30301
# 1         Atlanta, GA
# 2         Atlanta, GA
# 3  Atlanta, GA 30303
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     269 non-null    object
#  1   company      269 non-null    object
#  2   description  269 non-null    object
#  3   numreview    227 non-null    object
#  4   location     269 non-null    object
# dtypes: object(5)
# memory usage: 10.6+ KB

# %%
filter_null = df.isnull().any(axis=1)
df[filter_null]
# Out:
#                                               position  \
# 0                                 Development Director
# 1    An Ostentatiously-Excitable Principal Research...
# 2                                       Data Scientist
# 18                                      Data Scientist
# 19                                      Data Scientist
# 25                                      Data Scientist
# 26                Data Scientist 1 – AP Forensics Team
# 38                                      Data Scientist
# 48                       Chief Deep Learning Scientist
# 53                                 Statistical Analyst
# 54                                  VP, Data Analytics
# 55                             Lead Decision Scientist
# 65                                  Research Scientist
# 84                                  Research Scientist
# 106  Staff Research Scientist VII: Informational In...
# 114                            Jr Microbiologist - CDC
# ...

# %%
df[filter_null].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 267
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     42 non-null     object
#  1   company      42 non-null     object
#  2   description  42 non-null     object
#  3   numreview    0 non-null      object
#  4   location     42 non-null     object
# dtypes: object(5)
# memory usage: 2.0+ KB

# %% [markdown]
# **Terdapat 42 entries yang memiliki value Null dan semua NaN berada pada column numreview**

# %%
#Melakukan penggantian null dengan "0 reviews"
df_clean = df.copy()
df_clean = df.fillna("0 review",axis=0,inplace = False)
df_clean
# Out:
#                                               position  \
# 0                                 Development Director
# 1    An Ostentatiously-Excitable Principal Research...
# 2                                       Data Scientist
# 3                                         Data Analyst
# 4    Assistant Professor -TT - Signal Processing & ...
# ..                                                 ...
# 264                          Systems Software Engineer
# 265  Digital Marketing Consultant - Automotive Reta...
# 266                  Senior Packaging Engineer I - PET
# 267  Account Executive Fraud Solutions, Acquiring E...
# 268  Junior DevOps Software Engineer – Secureworks ...
#
#                       company  \
# 0                     ALS TDI
# 1          The Hexagon Lavish
# 2              Xpert Staffing
# 3              Operation HOPE
# 4            Emory University
# ..                        ...
# 264          Emory University
# 265                CDK Global
# ...

# %%
#Melakukan delete pada row yang mengandung Null
df_clean_row=df.copy()
df_clean_row=df.dropna(axis=0,inplace=False)
df_clean_row
# Out:
#                                               position  \
# 3                                         Data Analyst
# 4    Assistant Professor -TT - Signal Processing & ...
# 5                          Manager of Data Engineering
# 6         Product Specialist - Periscope, New Ventures
# 7    Junior to Mid-level Engineer, Geologist or Env...
# ..                                                 ...
# 263                       Software Researcher - CIPHER
# 264                          Systems Software Engineer
# 265  Digital Marketing Consultant - Automotive Reta...
# 266                  Senior Packaging Engineer I - PET
# 268  Junior DevOps Software Engineer – Secureworks ...
#
#                              company  \
# 3                     Operation HOPE
# 4                   Emory University
# 5                 McKinsey & Company
# 6                 McKinsey & Company
# 7                               Wood
# ..                               ...
# ...

# %%
df_clean_row.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227 entries, 3 to 268
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     227 non-null    object
#  1   company      227 non-null    object
#  2   description  227 non-null    object
#  3   numreview    227 non-null    object
#  4   location     227 non-null    object
# dtypes: object(5)
# memory usage: 10.6+ KB

# %%
df_clean_row.describe()
# Out:
#               position company  \
# count              227     227
# unique             208     100
# top     Data Scientist    KPMG
# freq                12      16
#
#                                               description      numreview  \
# count                                                 227            227
# unique                                                226             94
# top     <span id="job_summary" class="summary"><div><p...  4,494 reviews
# freq                                                    2             16
#
#            location
# count           227
# unique           20
# top     Atlanta, GA
# freq            114
