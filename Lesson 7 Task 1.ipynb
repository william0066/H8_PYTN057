# %%
import pandas as pd

# %%
df = pd.read_csv ("fulltimeAL.csv")

# %%
df
# Out:
#                                               position  \
# 0                                 Development Director
# 1    An Ostentatiously-Excitable Principal Research...
# 2                                       Data Scientist
# 3                                         Data Analyst
# 4    Assistant Professor -TT - Signal Processing & ...
# ..                                                 ...
# 264                          Systems Software Engineer
# 265  Digital Marketing Consultant - Automotive Reta...
# 266                  Senior Packaging Engineer I - PET
# 267  Account Executive Fraud Solutions, Acquiring E...
# 268  Junior DevOps Software Engineer – Secureworks ...
#
#                       company  \
# 0                     ALS TDI
# 1          The Hexagon Lavish
# 2              Xpert Staffing
# 3              Operation HOPE
# 4            Emory University
# ..                        ...
# 264          Emory University
# 265                CDK Global
# ...

# %%
df.company
# Out:
# 0                       ALS TDI
# 1            The Hexagon Lavish
# 2                Xpert Staffing
# 3                Operation HOPE
# 4              Emory University
#                  ...
# 264            Emory University
# 265                  CDK Global
# 266       The Coca-Cola Company
# 267    Payments & Cards Network
# 268                        DELL
# Name: company, Length: 269, dtype: object

# %%
filter_row = (df['position']) == "Data Scientist"
df [filter_row]
# Out:
#            position                company  \
# 2    Data Scientist         Xpert Staffing
# 15   Data Scientist               Cotiviti
# 18   Data Scientist            Relus Cloud
# 19   Data Scientist         Inspire Brands
# 22   Data Scientist  Norfolk Southern Corp
# 25   Data Scientist                AirSage
# 34   Data Scientist              SalesLoft
# 35   Data Scientist               McKesson
# 36   Data Scientist    The Intersect Group
# 38   Data Scientist            OM Partners
# 161  Data Scientist         Xpect SVC, LLC
# 208  Data Scientist       Matrix Resources
# 224  Data Scientist           Elavon, Inc.
# 229  Data Scientist     Cardinal Solutions
# 231  Data Scientist         Operation HOPE
# 233  Data Scientist  The Coca-Cola Company
# 238  Data Scientist              U.S. Bank
# 239  Data Scientist     Catalina Marketing
#
#                                            description      numreview  \
# ...

# %%
df_index = df.set_index ("position",inplace = False) #Set index

# %%
df_index
# Out:
#                                                                      company  \
# position
# Development Director                                                 ALS TDI
# An Ostentatiously-Excitable Principal Research ...        The Hexagon Lavish
# Data Scientist                                                Xpert Staffing
# Data Analyst                                                  Operation HOPE
# Assistant Professor -TT - Signal Processing & M...          Emory University
# ...                                                                      ...
# Systems Software Engineer                                   Emory University
# Digital Marketing Consultant - Automotive Retai...                CDK Global
# Senior Packaging Engineer I - PET                      The Coca-Cola Company
# Account Executive Fraud Solutions, Acquiring Ea...  Payments & Cards Network
# Junior DevOps Software Engineer – Secureworks –...                      DELL
#
# ...

# %%
df_index.loc["Data Scientist"]
# Out:
#                               company  \
# position
# Data Scientist         Xpert Staffing
# Data Scientist               Cotiviti
# Data Scientist            Relus Cloud
# Data Scientist         Inspire Brands
# Data Scientist  Norfolk Southern Corp
# Data Scientist                AirSage
# Data Scientist              SalesLoft
# Data Scientist               McKesson
# Data Scientist    The Intersect Group
# Data Scientist            OM Partners
# Data Scientist         Xpect SVC, LLC
# Data Scientist       Matrix Resources
# Data Scientist           Elavon, Inc.
# Data Scientist     Cardinal Solutions
# Data Scientist         Operation HOPE
# Data Scientist  The Coca-Cola Company
# Data Scientist              U.S. Bank
# Data Scientist     Catalina Marketing
#
#                                                       description  \
# position
# Data Scientist  <span id="job_summary" class="summary"><div><d...
# Data Scientist  <span id="job_summary" class="summary"><div><p...
# ...
