# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/Canada.xlsx?raw=true",sheet_name='Canada by Citizenship',skiprows=range(20),skipfooter=2)

# %%
df.head(5)
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2012  2013  \
# 0    Southern Asia  902  Developing regions    16  ...  2635  2004
# 1  Southern Europe  901   Developed regions     1  ...   620   603
# 2  Northern Africa  902  Developing regions    80  ...  3774  4331
# 3        Polynesia  902  Developing regions     0  ...     0     0
# 4  Southern Europe  901   Developed regions     0  ...     1     1
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
cols = list(range(43,51))
df.columns[cols]
df_can = df.drop(df.columns[cols], axis=1)
df_can
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0         Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# ...

# %%
df_can.describe(include ='all')

# %%
print (df_can[df_can.index == 'Japan'].T.squeeze())

# %%
filter_row = df_can ["AreaName"] == "Asia"
df_can [filter_row]

# %%
a= [1,2,3,4]
print (str(a))
b= list(map (str,a))
print (b)

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_can_drop = df_can.drop (["AreaName","RegName","DevName","Type","Coverage","AREA","REG","DEV"], axis =1)

# %%
#Setting "OdName" as Index & filter outcome as China
df_index = df_can_drop.set_index ("OdName",inplace = False)
df_can_China = df_index.loc ["China"]
df_can_China
# Out:
# 1980     5123
# 1981     6682
# 1982     3308
# 1983     1863
# 1984     1527
# 1985     1816
# 1986     1960
# 1987     2643
# 1988     2758
# 1989     4323
# 1990     8076
# 1991    14255
# 1992    10846
# 1993     9817
# 1994    13128
# 1995    14398
# 1996    19415
# 1997    20475
# 1998    21049
# 1999    30069
# 2000    35529
# 2001    36434
# 2002    31961
# 2003    36439
# 2004    36619
# 2005    42584
# 2006    33518
# 2007    27642
# 2008    30037
# 2009    29622
# 2010    30391
# 2011    28502
# 2012    33024
# 2013    34129
# Name: China, dtype: int64

# %%
df_can_China.plot()
plt.title ("Immigrant in Canada")
plt.ylabel ("Number of Imiggrant")
plt.xlabel ("Years")
plt.show()

# %%
df_can_China.plot(kind = "bar")
plt.title ("Immigrant in Canada")
plt.ylabel ("Number of Imiggrant")
plt.xlabel ("Years")
plt.show()

# %%
df_can_China.plot(kind ="line",figsize=(20,10)) #tipe chart & chart size)
plt.title ("Immigrant in Canada")
plt.ylabel ("Number of Imiggrant")
plt.xlabel ("Years")
plt.show()

# %%
df_index_transpose = df_index.T

# %%
df_index_transpose [["China", "Bhutan"]].plot(kind ="line",figsize=(20,10))
plt.title ("Immigrant in Canada")
plt.ylabel ("Number of Imiggrant")
plt.xlabel ("Years")
plt.show()

# %%
df_index ["Total"] = df_index.sum(axis=1)
df_total = df_index.sort_values(by="Total",ascending = False, axis =0,inplace =False)
df_total
# Out:
#                                                      1980   1981   1982  \
# OdName
# India                                                8880   8670   8147
# China                                                5123   6682   3308
# United Kingdom of Great Britain and Northern Ir...  22045  24796  20620
# Philippines                                          6051   5921   5249
# Pakistan                                              978    972   1201
# ...                                                   ...    ...    ...
# San Marino                                              1      0      0
# New Caledonia                                           0      0      0
# Marshall Islands                                        0      0      0
# Western Sahara                                          0      0      0
# Palau                                                   0      0      0
#
#                                                      1983   1984  1985  1986  \
# OdName
# ...

# %%
df_total_transpose = df_total.drop (["Total"],axis=1).head(5)
df_total_transpose_top5 = df_total_transpose.T
df_total_transpose_top5.plot (kind="line",figsize=(14,8))
plt.title ("Immigrant in Canada")
plt.ylabel ("Number of Imiggrant")
plt.xlabel ("Years")
plt.show()

# %%
count,bin_edges = np.histogram(data_canada_df_change_index[1980])
df_total_transpose_top5 ["India"].plot (kind="hist",figsize=(14,8))
plt.title ("Immigrant in Canada")
plt.ylabel ("Frequency")
plt.xlabel ("Number of Immigrant")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-19813b36b823> in <module>
# ----> 1 count,bin_edges = np.histogram(data_canada_df_change_index[1980])
#       2 df_total_transpose_top5 ["India"].plot (kind="hist",figsize=(14,8))
#       3 plt.title ("Immigrant in Canada")
#       4 plt.ylabel ("Frequency")
#       5 plt.xlabel ("Number of Immigrant")
#
# NameError: name 'data_canada_df_change_index' is not defined

# %%
df_continent =
